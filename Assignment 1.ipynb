# %%
#Assignment_1

# %%
l=[]
for n in range(2000, 3201):
    if (n%7==0) and (n%5!=0):
        l.append(i)
print(l)
# Out:
# [3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200, 3200]

# %%
#Assignment_2

# %%
f = input()
l = input()
s = (f +" "+ l)
n = s.split()
n = list(reversed(n))
print(" ".join(n))
# Out:
# ineuron
# assignment 2
# 2 assignment ineuron

# %%
#Assignment_3

# %%
r = 12
v = ((4/3)*3.1415*(r**3))
print(f"The volume of sphere is {v}")
# Out:
# The volume of sphere is 7238.016
