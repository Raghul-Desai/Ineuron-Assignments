# %% [markdown]
# # Write a function so that the columns of the output matrix are powers of the input
# vector.
# The order of the powers is determined by the increasing boolean argument. Specifically, when
# increasing is False, the i-th output column is the input vector raised element-wise to the power
# of N - i - 1.
#
# HINT: Such a matrix with a geometric progression in each row is named for Alexandre-
# Theophile Vandermonde.

# %%
import numpy as np

# %%
def AlexTheoVander(ipVector, n, increasing = False):
  if increasing:
    opMatrix = np.matrix([x**i for x in ipVector for i in range(n)]).reshape(ipVector.size, n)
  else:
    opMatrix = np.matrix([x**(n-i-1) for x in ipVector for i in range(n)]).reshape(ipVector.size, n)
  return opMatrix

# %%
ipVector = np.array([1, 3, 5, 7, 9])
n = 5

# %%
opMatrix_asc = AlexTheoVander(ipVector, n, True)
opMatrix_asc
# Out:
# matrix([[   1,    1,    1,    1,    1],
#         [   1,    3,    9,   27,   81],
#         [   1,    5,   25,  125,  625],
#         [   1,    7,   49,  343, 2401],
#         [   1,    9,   81,  729, 6561]])

# %%
opMatrix_desc = AlexTheoVander(ipVector, n, False)
opMatrix_desc
# Out:
# matrix([[   1,    1,    1,    1,    1],
#         [  81,   27,    9,    3,    1],
#         [ 625,  125,   25,    5,    1],
#         [2401,  343,   49,    7,    1],
#         [6561,  729,   81,    9,    1]])

# %% [markdown]
# # Write a function to find moving average in an array over a window:
# Test it over [3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150] and window of 3.

# %%
def movingAverage(inputValue, n):
  x = 1
  output = np.convolve(inputValue, np.ones(n), 'valid') / n
  for i in output:
    print("y{0} = {1:.2f}".format(x, i))
    x += 1

# %%
inputValue = np.array([3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150])
n = 3
movingAverage(inputValue, n)
# Out:
# y1 = 5.00
# y2 = 4.67
# y3 = 5.67
# y4 = 6.67
# y5 = 9.67
# y6 = 28.67
# y7 = 49.33
# y8 = 72.67
# y9 = 84.00
# y10 = 93.33
# y11 = 116.33
